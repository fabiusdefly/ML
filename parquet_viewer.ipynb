# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiusdefly/ML/blob/main/parquet_viewer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyarrow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# %%
parquet_file = '/content/contrats_assurances.parquet'

# %%
df = pd.read_parquet(parquet_file, engine='auto')
df
# Out:
#   ID_contrat_externe date_situation  flag_contrat_fin_annee  \
# 0             string     1970-01-01                    True
#
#    flag_nantissement ref_ext_contrat num_contrat ancien_num_contrat  \
# 0               True          string      string             string
#
#   ID_contrat_CCF code_agence date_effet_contrat  ... ID_intermediaire   ID_RM  \
# 0         string      string         1970-01-01  ...           string  string
#
#   ID_conseiller  VP_montant_unitaire VP_date_debut VP_periodicite  \
# 0        string                  0.1    1970-01-01         b'ANN'
#
#    RPP_montant_unitaire  RPP_montant_brut_ou_net  RPP_date_debut  \
# 0                   0.1                   string      1970-01-01
#
#    RPP_periodicite
# 0           b'ANN'
#
# [1 rows x 54 columns]

# %% [markdown]
# **Modification du fichier Parquet**

# %%
df[["code_role", "ref_ext_personne", "code_famille_produit", "date_cotation", "date_valorisation", "ref_ID_produit_CCF", "ID_support_composant", "ref_ID_support_info_generale", "ID_support_info_generale", "code_courant", "code_precedent", "designation"]] = "string"
df
# Out:
#   ID_contrat_externe date_situation  flag_contrat_fin_annee  \
# 0             string     1970-01-01                    True
#
#    flag_nantissement ref_ext_contrat num_contrat ancien_num_contrat  \
# 0               True          string      string             string
#
#   ID_contrat_CCF code_agence date_effet_contrat  ... code_famille_produit  \
# 0         string      string         1970-01-01  ...               string
#
#   date_cotation date_valorisation  ref_ID_produit_CCF ID_support_composant  \
# 0        string            string              string               string
#
#   ref_ID_support_info_generale  ID_support_info_generale  code_courant  \
# 0                       string                    string        string
#
#    code_precedent  designation
# 0          string       string
#
# [1 rows x 66 columns]

# %%
df.to_parquet('contrats_assurances3.parquet')
